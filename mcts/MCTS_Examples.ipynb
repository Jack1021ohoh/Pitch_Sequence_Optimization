# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Jack1021ohoh/Pitch_Sequence_Optimization.git
# %cd Pitch_Sequence_Optimization
# Out:
# Cloning into 'Pitch_Sequence_Optimization'...
# remote: Enumerating objects: 209, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 209 (delta 122), reused 148 (delta 61), pack-reused 0 (from 0)
# Receiving objects: 100% (209/209), 94.45 KiB | 6.75 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
# /content/Pitch_Sequence_Optimization

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.7/449.7 kB 37.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 60.3 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['DATA_DIR'] = '/content/drive/MyDrive/pitch_sequence/data'
os.environ['CKPT_DIR'] = '/content/drive/MyDrive/pitch_sequence/checkpoints'

# %% [markdown]
# ### Shohei Ohtani vs Paul Skenes

# %%
# Full count, 2 outs, runner on 3rd — need a strikeout
# %run mcts/run_search.py --batter-id 660271 --pitcher-id 694973 \
    --balls 3 --strikes 2 --outs 1 --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Runner on 1st, 1 out — double play situation, want ground ball
# %run mcts/run_search.py --batter-id 660271 --pitcher-id 694973 \
    --balls 0 --strikes 0 --outs 1 --on-1b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# First pitch of at-bat, bases loaded, 1 out — high leverage
# %run mcts/run_search.py --batter-id 660271 --pitcher-id 694973 \
    --balls 0 --strikes 0 --outs 1 --on-1b --on-2b --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Pitcher ahead 0-2, can waste a pitch
# %run mcts/run_search.py --batter-id 660271 --pitcher-id 694973 \
    --balls 0 --strikes 2 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Hitter's count 3-1, can't afford a walk
# %run mcts/run_search.py --batter-id 660271 --pitcher-id 694973 \
    --balls 3 --strikes 1 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %% [markdown]
# ### Juan Soto vs Zack Wheeler

# %%
# Full count, 2 outs, runner on 3rd — need a strikeout
# %run mcts/run_search.py --batter-id 665742 --pitcher-id 554430 \
    --balls 3 --strikes 2 --outs 1 --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Runner on 1st, 1 out — double play situation, want ground ball
# %run mcts/run_search.py --batter-id 665742 --pitcher-id 554430 \
    --balls 0 --strikes 0 --outs 1 --on-1b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# First pitch of at-bat, bases loaded, 1 out — high leverage
# %run mcts/run_search.py --batter-id 665742 --pitcher-id 554430 \
    --balls 0 --strikes 0 --outs 1 --on-1b --on-2b --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Pitcher ahead 0-2, can waste a pitch
# %run mcts/run_search.py --batter-id 665742 --pitcher-id 554430 \
    --balls 0 --strikes 2 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Hitter's count 3-1, can't afford a walk
# %run mcts/run_search.py --batter-id 665742 --pitcher-id 554430 \
    --balls 3 --strikes 1 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %% [markdown]
# ### Vladimir Guerrero Jr vs Tarik Skubal

# %%
# Full count, 2 outs, runner on 3rd — need a strikeout
# %run mcts/run_search.py --batter-id 665489 --pitcher-id 669373 \
    --balls 3 --strikes 2 --outs 1 --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Runner on 1st, 1 out — double play situation, want ground ball
# %run mcts/run_search.py --batter-id 665489 --pitcher-id 669373 \
    --balls 0 --strikes 0 --outs 1 --on-1b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# First pitch of at-bat, bases loaded, 1 out — high leverage
# %run mcts/run_search.py --batter-id 665489 --pitcher-id 669373 \
    --balls 0 --strikes 0 --outs 1 --on-1b --on-2b --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Pitcher ahead 0-2, can waste a pitch
# %run mcts/run_search.py --batter-id 665489 --pitcher-id 669373 \
    --balls 0 --strikes 2 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Hitter's count 3-1, can't afford a walk
# %run mcts/run_search.py --batter-id 665489 --pitcher-id 669373 \
    --balls 3 --strikes 1 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %% [markdown]
# ### Freddie Freeman VS Jesús Luzardo

# %%
# Full count, 2 outs, runner on 3rd — need a strikeout
# %run mcts/run_search.py --batter-id 518692 --pitcher-id 666200 \
    --balls 3 --strikes 2 --outs 1 --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Runner on 1st, 1 out — double play situation, want ground ball
# %run mcts/run_search.py --batter-id 518692 --pitcher-id 666200 \
    --balls 0 --strikes 0 --outs 1 --on-1b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# First pitch of at-bat, bases loaded, 1 out — high leverage
# %run mcts/run_search.py --batter-id 518692 --pitcher-id 666200 \
    --balls 0 --strikes 0 --outs 1 --on-1b --on-2b --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Pitcher ahead 0-2, can waste a pitch
# %run mcts/run_search.py --batter-id 518692 --pitcher-id 666200 \
    --balls 0 --strikes 2 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Hitter's count 3-1, can't afford a walk
# %run mcts/run_search.py --batter-id 518692 --pitcher-id 666200 \
    --balls 3 --strikes 1 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %% [markdown]
# ### Fernando Tatis Jr. VS Yoshinobu Yamamoto

# %%
# Full count, 2 outs, runner on 3rd — need a strikeout
# %run mcts/run_search.py --batter-id 665487 --pitcher-id 808967 \
    --balls 3 --strikes 2 --outs 1 --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Runner on 1st, 1 out — double play situation, want ground ball
# %run mcts/run_search.py --batter-id 665487 --pitcher-id 808967 \
    --balls 0 --strikes 0 --outs 1 --on-1b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# First pitch of at-bat, bases loaded, 1 out — high leverage
# %run mcts/run_search.py --batter-id 665487 --pitcher-id 808967 \
    --balls 0 --strikes 0 --outs 1 --on-1b --on-2b --on-3b --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Pitcher ahead 0-2, can waste a pitch
# %run mcts/run_search.py --batter-id 665487 --pitcher-id 808967 \
    --balls 0 --strikes 2 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...

# %%
# Hitter's count 3-1, can't afford a walk
# %run mcts/run_search.py --batter-id 665487 --pitcher-id 808967 \
    --balls 3 --strikes 1 --outs 0 --n-iter 15000
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# ...
