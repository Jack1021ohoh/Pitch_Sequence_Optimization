# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Jack1021ohoh/Pitch_Sequence_Optimization.git
# %cd Pitch_Sequence_Optimization
# Out:
# Cloning into 'Pitch_Sequence_Optimization'...
# remote: Enumerating objects: 298, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 298 (delta 4), reused 10 (delta 4), pack-reused 272 (from 1)
# Receiving objects: 100% (298/298), 155.27 KiB | 14.12 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/Pitch_Sequence_Optimization

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (18.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.6.1)
# Collecting pybaseball (from -r requirements.txt (line 5))
#   Downloading pybaseball-2.2.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (4.67.3)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (4.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: beautifulsoup4>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from pybaseball->-r requirements.txt (line 5)) (4.13.5)
# Requirement already satisfied: requests>=2.18.1 in /usr/local/lib/python3.12/dist-packages (from pybaseball->-r requirements.txt (line 5)) (2.32.4)
# Requirement already satisfied: lxml>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from pybaseball->-r requirements.txt (line 5)) (6.1.1)
# Collecting pygithub>=1.51 (from pybaseball->-r requirements.txt (line 5))
#   Downloading pygithub-2.9.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pybaseball->-r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: attrs>=20.3.0 in /usr/local/lib/python3.12/dist-packages (from pybaseball->-r requirements.txt (line 5)) (26.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.0->pybaseball->-r requirements.txt (line 5)) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.0->pybaseball->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pybaseball->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pybaseball->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pybaseball->-r requirements.txt (line 5)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pybaseball->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pybaseball->-r requirements.txt (line 5)) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pybaseball->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->pybaseball->-r requirements.txt (line 5)) (3.3.2)
# Collecting pynacl>=1.4.0 (from pygithub>=1.51->pybaseball->-r requirements.txt (line 5))
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball->-r requirements.txt (line 5)) (2.13.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pygithub>=1.51->pybaseball->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.1->pybaseball->-r requirements.txt (line 5)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.1->pybaseball->-r requirements.txt (line 5)) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.1->pybaseball->-r requirements.txt (line 5)) (2026.5.20)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub>=1.51->pybaseball->-r requirements.txt (line 5)) (48.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pynacl>=1.4.0->pygithub>=1.51->pybaseball->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->pynacl>=1.4.0->pygithub>=1.51->pybaseball->-r requirements.txt (line 5)) (3.0)
# Downloading pybaseball-2.2.7-py3-none-any.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 32.4 MB/s eta 0:00:00
# Downloading pygithub-2.9.1-py3-none-any.whl (449 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.7/449.7 kB 42.1 MB/s eta 0:00:00
# Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.5 MB/s eta 0:00:00
# Installing collected packages: pynacl, pygithub, pybaseball
# Successfully installed pybaseball-2.2.7 pygithub-2.9.1 pynacl-1.6.2

# %%
import os
os.environ['DATA_DIR'] = '/content/drive/MyDrive/pitch_sequence/data'
os.environ['CKPT_DIR'] = '/content/drive/MyDrive/pitch_sequence/checkpoints'

# %%
# !python -m training.train \
#       --epochs 10 \
#       --batch-size 256 \
#       --lr 1e-4 \
#       --workers 8 \
#       --patience 3 \
#       --class-weight-power 1.0

# %%
# !python -m training.train \
      --epochs 10 \
      --batch-size 256 \
      --lr 1e-4 \
      --workers 8 \
      --patience 3 \
      --class-weight-power 1.0 \
      --resume "$CKPT_DIR/latest.pt"
# Out:
# Device: cuda
# Building dataloaders...
# Building model...
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:50: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.app_encoder = nn.TransformerEncoder(app_layer, num_layers=n_app_layers)
# Resumed from epoch 5 (no-improve streak: 1)
# Parameters: 12,428,672
# Epoch 006 | 6025s | train loss 1.9306 (cls 2.2351 phy 1.7809 cal 0.0985) | val loss 2.0177 | val top-4 outcome 0.9601 location 0.6792
# Epoch 007 | 5963s | train loss 1.9376 (cls 2.2414 phy 1.7944 cal 0.0974) | val loss 2.0373 | val top-4 outcome 0.9492 location 0.6801
# Early stopping: no improvement for 3 epochs.
# Training complete.

# %%
# !python -m evaluation.evaluate \
      --checkpoint "$CKPT_DIR/best.pt" \
      --split test \
      --batch-size 256 \
      --workers 8
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /content/Pitch_Sequence_Optimization/models/batter_encoder.py:40: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:38: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.pitch_encoder = nn.TransformerEncoder(pitch_layer, num_layers=n_pitch_layers)
# /content/Pitch_Sequence_Optimization/models/pitcher_encoder.py:50: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.app_encoder = nn.TransformerEncoder(app_layer, num_layers=n_app_layers)
# Loaded checkpoint: /content/drive/MyDrive/pitch_sequence/checkpoints/best.pt (epoch 4)
# Evaluating on test split (509,062 samples)...
#
# ── Pitch Outcome ───────────────────────────────
#   Top-4 recall    : 0.9585
#   Top-1 accuracy  : 0.5793
#   Log-loss        : 1.0871
#   Brier score     : 0.5499
#   ECE             : 0.0871
#
#   Per-class Top-4 recall:
#     Ball            : 0.9762
#     Strike          : 0.9483
#     Single          : 0.9832
#     Double          : 0.4778
#     Triple          : 0.0000
#     Home Run        : 0.4723
#     Strikeout       : 0.9960
#     Walk            : 0.9910
#     Hit by Pitch    : 0.9779
#     Field Out       : 0.9979
#
# ── Hit Location ─────────────────────────────────
#   Top-4 recall    : 0.6869
#   Top-1 accuracy  : 0.2023
#   Log-loss        : 2.0564
#   Brier score     : 0.8564
#   ECE             : 0.0321
#
#   Per-class Top-4 recall:
#     Pitcher         : 0.5989
#     Catcher         : 0.2845
#     First Base      : 0.6399
#     Second Base     : 0.6400
#     Third Base      : 0.6454
#     Shortstop       : 0.6251
#     Left Field      : 0.7378
#     Center Field    : 0.7382
#     Right Field     : 0.7261
#     None            : 0.7625
#
# ── Physics (contact pitches only) ───────────────
#   EV NLL          : 0.1952
#   LA NLL          : 1.6354
#   EV MAE (mph)    : 9.87
#   LA MAE (deg)    : 20.09
